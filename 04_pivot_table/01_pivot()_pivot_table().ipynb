# %%
import pandas as pd

# %%
# read the csv file and display the data frame
df_gdp = pd.read_csv('gdp.csv')
df_gdp
# Out:
#       unid wbid      country  year        SES       gdppc  yrseduc  popshare
# 0        4  AFG  Afghanistan  1970   3.474212   709.00000      NaN  0.003097
# 1        4  AFG  Afghanistan  1920  26.968016   731.75677      NaN  0.003245
# 2        4  AFG  Afghanistan  1990   1.269530   604.00000      NaN  0.002347
# 3        4  AFG  Afghanistan  1960  15.763076   739.00000      NaN  0.003039
# 4        4  AFG  Afghanistan  2000   2.061114   565.00000      NaN  0.003309
# ...    ...  ...          ...   ...        ...         ...      ...       ...
# 1979   858  URY      Uruguay  1910  78.526253  3136.00000   2.5900  0.000611
# 1980   858  URY      Uruguay  1990  71.591408  9840.72660   7.4745  0.000605
# 1981   858  URY      Uruguay  1970  74.391846  5184.00000   5.6790  0.000783
# 1982   858  URY      Uruguay  1940  78.112961  3661.00000   3.8300  0.000846
# 1983   858  URY      Uruguay  1880  86.436966  2082.00000   2.1400  0.000333
#
# [1984 rows x 8 columns]

# %% [markdown]
# ## .pivot()

# %%
# reshape the dataframe with .pivot()
df_gdp_pivot = df_gdp.pivot(index='country', columns='year', values='gdppc')
df_gdp_pivot
# Out:
# year                        1880        1890        1900        1910  \
# country
# Afghanistan            585.46509   635.93024   686.39532   736.86047
# Albania                522.00000   598.00000   685.00000   780.00000
# Algeria                819.18604   923.37207  1027.55810  1131.74410
# Angola                 533.66669   567.33331   601.00000   628.69232
# Argentina             1731.50000  2152.00000  2756.00000  3822.00000
# ...                          ...         ...         ...         ...
# Uganda                 533.66669   567.33331   601.00000   628.69232
# Ukraine               1041.00000  1139.00000  1237.00000  1430.07690
# United Arab Emirates   811.76746   881.53491   951.30231  1021.06980
# United Kingdom        3477.00000  4009.00000  4492.00000  4611.00000
# Uruguay               2082.00000         NaN         NaN  3136.00000
#
# year                        1920        1930         1940     1950     1960  \
# country
# ...

# %% [markdown]
# ## .pivot_table()

# %%
# read the excel file and display the data frame
df_sales = pd.read_excel('supermarket_sales.xlsx')
df_sales
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# make a pivot table, add an aggregate function and select some columns 
df_sales.pivot_table(index='Gender',
                     values=['Quantity', 'Total'],
                     aggfunc='sum').round(1)
# Out:
#         Quantity     Total
# Gender
# Female      2869  167882.9
# Male        2641  155083.8

# %%
# make a pivot tables that says how much male and female spend in each category
df_sales.pivot_table(index='Gender',
                     columns='Product line',
                     values='Total',
                     aggfunc='mean').round(1)
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Gender
# Female                         322.6                317.1               368.6
# Male                           316.7                291.1               273.5
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Gender
# Female                    290.0               380.2              324.7
# Male                      348.1               294.1              340.4
