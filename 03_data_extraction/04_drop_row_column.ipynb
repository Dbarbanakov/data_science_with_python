# %%
import pandas as pd

# %%
# reads csv file
df = pd.read_csv('players_20.csv')
# set index
df.set_index('short_name', inplace=True)
# select column
df = df[['long_name', 'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club']]

# %%
# show dataframe
df.head(3)
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
#
#                    height_cm  weight_kg nationality                 club
# short_name
# L. Messi                 170         72   Argentina         FC Barcelona
# Cristiano Ronaldo        187         83    Portugal             Juventus
# Neymar Jr                175         68      Brazil  Paris Saint-Germain

# %% [markdown]
# ### Drop Rows

# %%
# drop one row
# axis parameter
df.drop('L. Messi', axis=0).head(3)
# Out:
#                                              long_name  age         dob  \
# short_name
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
#
#                    height_cm  weight_kg nationality                 club
# short_name
# Cristiano Ronaldo        187         83    Portugal             Juventus
# Neymar Jr                175         68      Brazil  Paris Saint-Germain
# J. Oblak                 188         87    Slovenia      Atlético Madrid

# %%
# index parameter
d.head(3)f.drop(index=['Cristiano Ronaldo']).head(3)
# Out:
#                                  long_name  age         dob  height_cm  \
# short_name
# L. Messi    Lionel Andrés Messi Cuccittini   32  1987-06-24        170
# Neymar Jr    Neymar da Silva Santos Junior   27  1992-02-05        175
# J. Oblak                         Jan Oblak   26  1993-01-07        188
#
#             weight_kg nationality                 club
# short_name
# L. Messi           72   Argentina         FC Barcelona
# Neymar Jr          68      Brazil  Paris Saint-Germain
# J. Oblak           87    Slovenia      Atlético Madrid

# %%
# drop two or more rows and update data (inplace=True)
df.drop(['L. Messi', 'Cristiano Ronaldo'], inplace=True)

# %%
df.head(3)
# Out:
#                                 long_name  age         dob  height_cm  \
# short_name
# Neymar Jr   Neymar da Silva Santos Junior   27  1992-02-05        175
# J. Oblak                        Jan Oblak   26  1993-01-07        188
# E. Hazard                     Eden Hazard   28  1991-01-07        175
#
#             weight_kg nationality                 club
# short_name
# Neymar Jr          68      Brazil  Paris Saint-Germain
# J. Oblak           87    Slovenia      Atlético Madrid
# E. Hazard          74     Belgium          Real Madrid

# %% [markdown]
# ### Drop Columns

# %%
# drop one column
# axis parameter
df.drop('long_name', axis=1).head(3)
# Out:
#             age         dob  height_cm  weight_kg nationality  \
# short_name
# Neymar Jr    27  1992-02-05        175         68      Brazil
# J. Oblak     26  1993-01-07        188         87    Slovenia
# E. Hazard    28  1991-01-07        175         74     Belgium
#
#                            club
# short_name
# Neymar Jr   Paris Saint-Germain
# J. Oblak        Atlético Madrid
# E. Hazard           Real Madrid

# %%
# index parameter
df.drop(columns=['long_name']).head(3)
# Out:
#             age         dob  height_cm  weight_kg nationality  \
# short_name
# Neymar Jr    27  1992-02-05        175         68      Brazil
# J. Oblak     26  1993-01-07        188         87    Slovenia
# E. Hazard    28  1991-01-07        175         74     Belgium
#
#                            club
# short_name
# Neymar Jr   Paris Saint-Germain
# J. Oblak        Atlético Madrid
# E. Hazard           Real Madrid

# %%
# drop column by position/index (drop last column)
df.drop(df.columns[[-1]], axis=1).head(3)
# Out:
#                                 long_name  age         dob  height_cm  \
# short_name
# Neymar Jr   Neymar da Silva Santos Junior   27  1992-02-05        175
# J. Oblak                        Jan Oblak   26  1993-01-07        188
# E. Hazard                     Eden Hazard   28  1991-01-07        175
#
#             weight_kg nationality
# short_name
# Neymar Jr          68      Brazil
# J. Oblak           87    Slovenia
# E. Hazard          74     Belgium

# %%
# drop two or more columns and update data (inplace=True)
df.drop(columns=['long_name', 'age'], inplace=True)

# %%
df.head(3)
# Out:
#                    dob  height_cm  weight_kg nationality                 club
# short_name
# Neymar Jr   1992-02-05        175         68      Brazil  Paris Saint-Germain
# J. Oblak    1993-01-07        188         87    Slovenia      Atlético Madrid
# E. Hazard   1991-01-07        175         74     Belgium          Real Madrid
