# %%
import pandas as pd

# %%
df_movies = pd.read_csv('IMDb movies.csv', low_memory=False)
df_ratings = pd.read_csv('IMDb ratings.csv')

# %%
# select columns
df_movies = df_movies[['imdb_title_id', 'title', 'year',
                       'genre', 'country', 'director', 'actors']]

df_ratings = df_ratings[['imdb_title_id', 'total_votes', 'mean_vote']]

# %% [markdown]
# ## concat()

# %% [markdown]
# ### Concatenate vertically

# %% [markdown]
# To concatenate vertically (along the rows) we should have columns in common between the 2 dataframes

# %%
df1 = pd.DataFrame({'id': ['A', 'B', 'C', 'D'],
                    'age': [30, 23, 25, 22]})
df2 = pd.DataFrame({'id': ['E', 'F', 'G', 'F'],
                    'age': [40, 21, 19, 24]})

# %%
pd.concat([df1, df2])
# Out:
#   id  age
# 0  A   30
# 1  B   23
# 2  C   25
# 3  D   22
# 0  E   40
# 1  F   21
# 2  G   19
# 3  F   24

# %%
# extract a 50% sample of the original dataframe
df_half = df_movies.sample(frac=0.5)
print(df_movies.shape)
df_half.shape
# Out:
# (85855, 7)
# (42928, 7)

# %%
# concatenate df_movies and df_sample (vertically along the rows)
df_vertical_concat = pd.concat([df_movies, df_half], axis=0)
df_vertical_concat.head(3)
# Out:
#   imdb_title_id                        title  year                    genre  \
# 0     tt0000009                   Miss Jerry  1894                  Romance
# 1     tt0000574  The Story of the Kelly Gang  1906  Biography, Crime, Drama
# 2     tt0001892               Den sorte drøm  1911                    Drama
#
#             country         director  \
# 0               USA  Alexander Black
# 1         Australia     Charles Tait
# 2  Germany, Denmark        Urban Gad
#
#                                               actors
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...

# %%
df_vertical_concat.shape
# Out:
# (128783, 7)

# %% [markdown]
# ### Concatenate horizontally

# %% [markdown]
# To concatenate horizontally (along the columns) we should have a common index between the 2 dataframes

# %%
df1 = pd.DataFrame({'id': ['A', 'B', 'C', 'D'],
                    'age': [30, 23, 25, 22]})
df2 = pd.DataFrame({'job': ['Doctor', 'Statistician',
                            'Accountant', 'Developer']})

# %%
pd.concat([df1,df2], axis=1)
# Out:
#   id  age           job
# 0  A   30        Doctor
# 1  B   23  Statistician
# 2  C   25    Accountant
# 3  D   22     Developer

# %%
# shape of dataframes that we'll concatenate
print(df_movies.shape)
print(df_ratings.shape)
# Out:
# (85855, 7)
# (85855, 3)

# %%
# check column names so we can choose an appropriate index to concatenate on
print(df_movies.columns)
print(df_ratings.columns)
# Out:
# Index(['imdb_title_id', 'title', 'year', 'genre', 'country', 'director',
#        'actors'],
#       dtype='object')
# Index(['imdb_title_id', 'total_votes', 'mean_vote'], dtype='object')

# %%
# concatenate df_movies and df_ratings on 'imdb_title_id' (horizontally along the columns)
df_horizontal_concat = pd.concat([df_movies.set_index('imdb_title_id'), df_ratings.set_index('imdb_title_id')], axis=1)
df_horizontal_concat
# Out:
#                                         title  year  \
# imdb_title_id
# tt0000009                          Miss Jerry  1894
# tt0000574         The Story of the Kelly Gang  1906
# tt0001892                      Den sorte drøm  1911
# tt0002101                           Cleopatra  1912
# tt0002130                           L'Inferno  1911
# ...                                       ...   ...
# tt9908390                             Le lion  2020
# tt9911196      De Beentjes van Sint-Hildegard  2020
# tt9911774           Padmavyuhathile Abhimanyu  2019
# tt9914286                   Sokagin Çocuklari  2019
# tt9914942          La vida sense la Sara Amat  2019
#
#                                    genre           country  \
# imdb_title_id
# tt0000009                        Romance               USA
# tt0000574        Biography, Crime, Drama         Australia
# tt0001892                          Drama  Germany, Denmark
# tt0002101                 Drama, History               USA
# tt0002130      Adventure, Drama, Fantasy             Italy
# ...                                  ...               ...
# tt9908390                         Comedy   France, Belgium
# tt9911196                  Comedy, Drama       Netherlands
# tt9911774                          Drama             India
# tt9914286                  Drama, Family            Turkey
# tt9914942                          Drama             Spain
#
#                                           director  \
# imdb_title_id
# tt0000009                          Alexander Black
# tt0000574                             Charles Tait
# tt0001892                                Urban Gad
# tt0002101                       Charles L. Gaskill
# tt0002130      Francesco Bertolini, Adolfo Padovan
# ...                                            ...
# tt9908390                   Ludovic Colbeau-Justin
# tt9911196                          Johan Nijenhuis
# tt9911774                          Vineesh Aaradya
# tt9914286                        Ahmet Faik Akinci
# tt9914942                                Laura Jou
#
#                                                           actors  total_votes  \
# imdb_title_id
# tt0000009      Blanche Bayliss, William Courtenay, Chauncey D...          154
# tt0000574      Elizabeth Tait, John Tait, Norman Campbell, Be...          589
# tt0001892      Asta Nielsen, Valdemar Psilander, Gunnar Helse...          188
# tt0002101      Helen Gardner, Pearl Sindelar, Miss Fielding, ...          446
# tt0002130      Salvatore Papa, Arturo Pirovano, Giuseppe de L...         2237
# ...                                                          ...          ...
# tt9908390      Dany Boon, Philippe Katerine, Anne Serra, Samu...          398
# tt9911196      Herman Finkers, Johanna ter Steege, Leonie ter...          724
# tt9911774      Anoop Chandran, Indrans, Sona Nair, Simon Brit...          265
# tt9914286      Ahmet Faik Akinci, Belma Mamati, Metin Keçeci,...          194
# tt9914942      Maria Morera Colomer, Biel Rossell Pelfort, Is...          102
#
#                mean_vote
# imdb_title_id
# tt0000009            5.9
# tt0000574            6.3
# tt0001892            6.0
# tt0002101            5.3
# tt0002130            6.9
# ...                  ...
# tt9908390            5.5
# tt9911196            7.9
# tt9911774            7.8
# tt9914286            9.4
# tt9914942            6.8
#
# [85855 rows x 8 columns]
